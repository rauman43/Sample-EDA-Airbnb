# %% [markdown]
# <a href="https://colab.research.google.com/github/rauman43/Sample-EDA-Airbnb/blob/main/Capstone_Project_AIRBNB_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# Airbnb is an online marketplace and platform for hospitality services that enables people to rent out their homes, apartments, and rooms to tourists who are looking for short-term lodging.Since its launch in 2008, Airbnb has allowed both hosts and visitors to extend their travel options and offer a more distinctive, customized travel experience. These days, Airbnb has evolved into a unique service that is utilized and acknowledged globally.
# The original goal of Airbnb, according to its founders Brian Chesky, Joe Gebbia, and Nathan Blecharczyk, was to develop a platform that would assist residents in renting out a spare room in their house or apartment to tourists, giving them the chance to make extra money from their vacant space. The goal was to provide travelers with a more unique and intimate experience that would enable them to interact with locals and see a place from a different angle.
#
# The tenet of their philosophy revolved around the notion of "home-sharing" and the expectation that the platform would create a feeling of global community by connecting hosts and visitors. The platform's creators aimed to foster mutual respect, safety, and trust between hosts and visitors but as the site became exponentially more popular over time, some hosts stopped using Airbnb as a side gig and started using it full-time. This raised questions about how it would affect the supply and affordability of housing in some cities. Critics claimed that some hosts were listing multiple properties on Airbnb as short-term rentals instead of listing them on the long-term rental market, which resulted in higher rents and less housing options for locals.
#
# Therefore, as local governments and legislators struggled to strike a balance between the advantages of short-term rentals and their possible detrimental effects on housing and local communities, Airbnb was subject to criticism and regulatory challenges in a number of cities.
# As a result of these worries, Airbnb has put in place a number of rules and guidelines to address problems with housing supply, taxes, and community impact in various locations. The platform keeps changing in an effort to balance the original idea of home-sharing with addressing the problems brought on by its quick expansion and commercialization.
#
# Airbnb Business Model:
#  How does Airbnb use its web platform to link hosts and guests?
# Through its online platform, Airbnb links hosts and guests by offering a simple and effective interface that streamlines the entire booking process. An outline of how the platform links hosts and guests is provided below:
# 1. Listing Creation: Using Airbnb's mobile app or website, hosts can create comprehensive listings for their properties. They give details about the property, such as its location, amenities, kind (e.g., private room, shared room, entire home), and house rules.
# 2. Search and Discovery: Based on their travel dates, preferred locations, spending limit, and other factors, guests utilize Airbnb's search feature to locate acceptable lodging. Listings can be filtered by amenities, property type, price, and location.
#
#   3.Booking Request: Upon discovering a listing that piques their interest, visitors have the option to submit a booking request to the host, indicating their preferred dates of stay. Depending on their availability and other considerations, the host may choose to approve or reject the request.
#
#
#
#
#  Analysis of data on millions of listings made available by Airbnb is vital to the business. A vast amount of data is generated by these millions of listings. This data can be analyzed and utilized for a variety of purposes, including security, business decision-making, understanding customer and provider behavior and performance on the platform, directing marketing campaigns, implementing creative extra services, and much more.
# This dataset, which consists of 16 columns and over 49,000 observations, combines numeric and category information.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# This is the most important part of any analysis as we must understand the needs of a customer/business owner for what task they require analysis on and work as per their requirements. The main motive was to analyze the given dataset to provide the company with the information that will help to analyze their business and take strategically important decisions to further grow their business to new heights.

# %% [markdown]
# The principal aim of this project is to enhance the client's Airbnb rental enterprise in New York City through the optimization of occupancy rates, profitability, and guest contentment. The goal is to raise occupancy rates, boost income, and guarantee great guest experiences by putting data-driven strategies and insights into practice. This will ultimately propel the client's business to success and growth in the cutthroat NYC Airbnb market.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/'

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### Dataset Loading

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# Importing Dataset From Drive

# %%
df = pd.read_csv(path + '/content/drive/MyDrive/Dataset/Airbnb NYC 2019 (1).csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-71635b9f1f24> in <cell line: 1>()
# ----> 1 df = pd.read_csv(path + '/content/drive/MyDrive/Dataset/Airbnb NYC 2019 (1).csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
# Load Dataset
import pandas as pd
df = pd.read_csv('Airbnb NYC 2019 (1).csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-f134eabc40db> in <cell line: 3>()
#       1 # Load Dataset
#       2 import pandas as pd
# ----> 3 df = pd.read_csv('Airbnb NYC 2019 (1).csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import pandas as pd
import os.path
if os.path.exists("Airbnb NYC 2019 (1).csv"):
  print("File exists.")
else:
    print("File does not exist.")
# Read the CSV file and assign it to df
df = pd.read_csv('/content/drive/MyDrive/Dataset/Airbnb NYC 2019 (1).csv')
# Now you can use df.info() to get information about the DataFrame
# Out:
# File does not exist.

# %% [markdown]
# ### Dataset First View

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
#Lets check the file head upto last 5 entries:
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#Lets check the file tail upto last 5 entries:
df.tail(5)
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %% [markdown]
# As we can see most number of listings are from Manhattan created Sonder (NYC), Blueground, Michael, David

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
#Lets have a quick overview of data info:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
#identify duplicate rows
df.duplicated().value_counts()
# Out:
# False    48895
# dtype: int64

# %%
df.duplicated(keep='first')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Length: 48895, dtype: bool

# %% [markdown]
# #### Missing Values/Null Values

# %% [markdown]
# A Dataset may contain lots of data as null values. These null values may cause error while executing any code or while plotting graphs. So, this null values must be checked before operating on data.

# %%
# Missing Values/Null Values Count
df.isnull().sum().sort_values(ascending=False)
# Out:
# last_review                       10052
# reviews_per_month                 10052
# host_name                            21
# name                                 16
# id                                    0
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing
import seaborn as sns
plt.figure(figsize=(5, 3))
sns.heatmap(df.isnull(), cbar=False, cmap='Reds')
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains 48895 rows and 16 columns covering data like neighbourhood_group, latitude, longitude, room_type,number_of_reviews, price, minimum_nights, number of reviews etc. There are no duplicate values. A significant number of values seem to be missing from the last_review and reviews_per_month columns. Variables include a mix of numeric and categorical data types. There are five different neighborhood groups, 221 neighborhoods, 37,457 hosts, 48,895 listings, and three types of room available for rental. This seems like a clean dataset that is ready for analysis and visualization to draw insights.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Quantitative Variables: latitude longitude price minimum_nights number_of_reviews reviews_per_month calculated_host_listings_count availability_365 Categorical Variables: id name host_id host_name neighbourhood_group neighbourhood room_type last_reListings are there

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in",i,"is",df[i].nunique())
# Out:
# No. of unique values in id is 48895
# No. of unique values in name is 47905
# No. of unique values in host_id is 37457
# No. of unique values in host_name is 11452
# No. of unique values in neighbourhood_group is 5
# No. of unique values in neighbourhood is 221
# No. of unique values in latitude is 19048
# No. of unique values in longitude is 14718
# No. of unique values in room_type is 3
# No. of unique values in price is 674
# No. of unique values in minimum_nights is 109
# No. of unique values in number_of_reviews is 394
# No. of unique values in last_review is 1764
# No. of unique values in reviews_per_month is 937
# No. of unique values in calculated_host_listings_count is 47
# No. of unique values in availability_365 is 366

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Before doing any data wrangling lets create copy of the dataset
df2 = df.copy()

# %%
# Checking the number of rows with zero price values in our dataset.
df2[df2.price==0].shape
# Out:
# (11, 16)

# %%
# Removing rows having zero price values from our dataset.
df2 = df2[df2['price'] !=0]

# %% [markdown]
# Name, host name, last review, and reviews_per_month are the columns that have missing values; the last two have missing values totaling more than 10,000 rows each.
#
# Since it can be interesting to analyze the number of reviews per month, it is best to deal with this column by replacing all NaN values with zeros. Similarly, host names and names are not very important to our analysis, so we can at least fill those in both columns with some substitutes.
#
# It is recommended to remove the last_review column since it will not be utilized in this analysis.

# %%
# Since both 'name' and 'host_name' has very less missing values as compared to the
# Entire dataset we can fill these missing values in both with unknown & no_name respectively!
df2['name'].fillna('unknown',inplace=True)
df2['host_name'].fillna('anonymous',inplace=True)

# %%
# Checks if any null values still exist!
df2[['host_name','name']].isnull().values.any()
# Out:
# False

# %%
# Filling null values in reviews_per_month column with 0
df2['reviews_per_month'] = df['reviews_per_month'].fillna(0)

# %%
# Drop the last_review column
df2.drop(['last_review'], axis=1, inplace=True)

# %%
# Checking change in shape
df2.shape
# Out:
# (48884, 15)

# %% [markdown]
# Previous shape was (48895, 16) and the shape of the new data frame created after cleaning is (48884, 15) Hence correctly removed 11 rows where the price value was 0

# %%
# Checking the changes
df2.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
##HANDLING THE OUTLIERS
Outliers in the price column
# Out:
#   File "<ipython-input-40-ecfa47c1d891>", line 2
#     Outliers in the price column;
#                     ^
# SyntaxError: invalid syntax

# %%
# Boxplot of 'price' column
sns.boxplot(df2['price'], color='#cafe48')
# Out:
# <Axes: >

# %% [markdown]
# Removing Outliers using IQR approach! (has performed best in removing outliers)

# %%
# Calculate the IQR and boundaries
Q1 = df2['price'].quantile(0.25)
Q3 = df2['price'].quantile(0.75)
IQR = Q3 - Q1
lower_boundary = Q1 - 1.5 * IQR
upper_boundary = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
df2 = df2[(df2['price'] >= lower_boundary) & (df2['price'] <= upper_boundary)]

# %%
sns.boxplot(df2['price'], color='#cafe48') #the boxplot for price now looks good without outliers!
# Out:
# <Axes: >

# %%
# Distribution Plot of 'price' column
sns.distplot(df2['price'], color='#f05d5e')
# Out:
# <ipython-input-47-9c6c805cdaad>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['price'], color='#f05d5e')
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
#               Outliers in the minimum nights column

# %%
# Calculate the IQR and boundaries
Q1 = df2['minimum_nights'].quantile(0.25)
Q3 = df2['minimum_nights'].quantile(0.75)
IQR = Q3 - Q1
lower_boundary = Q1 - 1.5 * IQR
upper_boundary = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
df2 = df2[(df2['minimum_nights'] >= lower_boundary) & (df2['minimum_nights'] <= upper_boundary)]

# %%
# Boxplot of 'minimum_nights' column without outliers
sns.boxplot(df2['minimum_nights'], color='#cafe48')
# The boxplot for minimum nights now looks good without outliers!
# Out:
# <Axes: >

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %%
#Lets check the statistical value(mean, median) of all feature of neighbourbood group wise

df_mean_median = df2[['neighbourhood_group','price','minimum_nights','number_of_reviews','availability_365']]
#defining a function get_mean_median_mode to fing mean and median
def get_mean_median(data,neighbourhood_group):
  ''' This fuction gives mean and median of all features'''
  # try block to utilize eror handling
  try:
    return pd.concat([df_mean_median[df_mean_median['neighbourhood_group']==neighbourhood_group].describe().round(2).iloc[1],
          df_mean_median[df_mean_median['neighbourhood_group']==neighbourhood_group].describe().round(2).iloc[5]], axis = 1).rename(columns={'50%':'Median'})
  # except block to catch error
  except:
    print("Invalid Neighbourhood Group")


# using a for loop to print the mean and median for all unique values from the neighborhood group
for i in df.neighbourhood_group.unique():
  print(i,get_mean_median(df_mean_median,i))
  print('\n')
# Out:
# Brooklyn                      mean  Median
# price              103.27    90.0
# minimum_nights       2.80     2.0
# number_of_reviews   26.21     7.0
# availability_365    90.78    17.0
#
#
# Manhattan                      mean  Median
# price              134.73   125.0
# minimum_nights       2.74     2.0
# number_of_reviews   25.54     6.0
# availability_365    80.96     7.0
#
#
# Queens                      mean  Median
# price               88.45    75.0
# minimum_nights       2.28     2.0
# number_of_reviews   30.19     9.0
# availability_365   140.68    90.0
#
#
# Staten Island                      mean  Median
# price               85.19    75.0
# minimum_nights       2.34     2.0
# number_of_reviews   33.28    16.0
# availability_365   199.54   219.0
#
#
# Bronx                      mean  Median
# price               75.25    65.0
# minimum_nights       2.26     2.0
# number_of_reviews   27.70     9.0
# availability_365   161.21   136.0

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1  Column wise Histogram and Box Plot

# %%
# Chart - 1 visualization code
for col in df2.describe().columns:
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

    # Histogram plot
    sns.histplot(df2[col], ax=axes[0], kde=True, color='#05204a', edgecolor='white')
    axes[0].set_xlabel(col)
    axes[0].set_ylabel('Frequency')
    axes[0].set_title("Distribution of " + col, fontsize=15)
    axes[0].grid(True, linestyle='--')

    # Boxplot
    sns.boxplot(df2[col], ax=axes[1], orient='h', showmeans=True, color='#cafe48')
    axes[1].set_xlabel(col)
    axes[1].set_ylabel('')
    axes[1].set_title("Boxplot of " + col, fontsize=15)
    axes[1].grid(True, linestyle='--')

    # Adjust spacing between subplots
    plt.tight_layout()

    # Show the plots
    plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *   A histplot is a kind of chart used to show a dataset's distribution. It is a graphical depiction of the data that indicates the frequency at which each value or set of values occurs. Histplots are helpful for deciphering a dataset's distribution and spotting trends or patterns in the information. When working with large data sets (more than 100 observations), it is also helpful. It can assist in identifying any gaps in the data or anomalous observations (outliers).
#
# *  In order to determine whether or not the variable distributions throughout the entire dataset are symmetric, we employed the histogram plot.
#
# *   A boxplot is a single plot that displays the median, quartiles, and range of a dataset along with other important statistical details. Boxplots can be used to compare the distribution of several datasets, find out whether a dataset contains outliers, and determine how dispersed the data is. They are frequently employed in data visualization and statistical analysis.
#
# *  Thus, for each numerical varibale in the given dataset, I used box
# plot to analyse the outliers and interquartile range including median, maximum and minimum value.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   From above distribution charts we can see that, not all columns are symmetrically distributed and the mean and median are ranging the same is for numerical columns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *  Histogram and Box plot cannot give us whole information regarding data. It's done just to see the distribution of the column data over the dataset.

# %% [markdown]
# #### Chart - 2   What is the average price for each neighbourhood group?

# %%
# Chart - 2 visualization code
# Group the dataset by "Neighbourhood group" and calculate the average price
neighborhood_avg_price = df2.groupby('neighbourhood_group')['price'].mean()

# Set the style of the plot
sns.set(style="whitegrid")

# Create a bar plot with custom color palette
plt.figure(figsize=(10, 6))
colors = ['#272932', '#f05d5e', '#0f7173', '#9fc2cc', '#dbc648']
ax = sns.barplot(x=neighborhood_avg_price.index, y=neighborhood_avg_price, palette=colors)

# Set the title and axis labels
plt.title('Neighbourhood Group vs. Average Price', fontsize=16)
plt.xlabel('Neighbourhood Group', fontsize=12)
plt.ylabel('Average Price', fontsize=12)
plt.xticks(rotation=30)

# Add value labels on top of each bar
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points', fontsize=10)

# Remove the top and right spines
sns.despine()

#display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *   When comparing the average prices of various neighborhood groups in the Airbnb
# 2019 NYC data set, a bar plot is a useful visualization technique. Each bar in the neighborhood is a representation of a different neighborhood group, and its height reflects the average price. Trends are easy to interpret and identify with this visual representation. The heights of the bars allow viewers to quickly compare which neighborhood groups typically have higher or lower average prices. A bar plot is an effective tool for comprehending and evaluating the average prices among the various neighborhood groups in the data set because of its simple and straightforward design.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Analyzing the average prices of different neighborhood groups in the Airbnb
# 2019 NYC data set using a bar plot can provide valuable insights.
#
# *   By visually comparing the heights of the bars, we can identify which neighborhoods have higher or lower average prices.
# This information is crucial for both hosts and guests.
#
# *   Hosts can adjust their pricing strategies based on neighborhoods that tend to command higher prices.
#
# *   Guests can make informed decisions about where to book accommodations based on their budget and preferences.
#
# *   The ordered arrangement of the bars can reveal trends, highlighting consistent higher or lower average prices in certain neighborhood groups.
#
# *   This analysis helps stakeholders in the Airbnb market understand price variations across neighborhood groups.
#
# *   It enables them to make data-driven decisions and optimize their experiences in the NYC market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *  The analysis can have a positive business impact by helping hosts strategically set prices and maximize profits.
#
# *   It enables guests to find accommodations within their desired budget.
# Lower average prices in certain neighborhoods may indicate a lack of demand or less desirable features.
#
# *  Focusing solely on high-priced neighborhoods may lead to increased competition and saturation, driving down prices.
#
# *   Hosts should consider factors beyond average prices, such as location amenities and uniqueness of their listings.
#
# *  Maintaining competitive pricing strategies across diverse neighborhoods can mitigate the risks associated with price variations.
#
# *   The insights can assist hosts in optimizing their listings and appealing to a broader range of guests

# %% [markdown]
# #### Chart - 3  Which neighbourhood group has the highest number of listings?

# %%
# Chart - 3 visualization

#using a pivot plot
df2_pivot = pd.pivot_table(df2, index=['neighbourhood_group'], values='id', aggfunc=['count'], margins=True, margins_name='Total Count')
df2_pivot
# Out:
#                      count
#                         id
# neighbourhood_group
# Bronx                  996
# Brooklyn             17005
# Manhattan            15122
# Queens                4963
# Staten Island          337
# Total Count          38423

# %% [markdown]
# By creating a pivot table of the total number of listings grouped by the different boroughs, we learn that out of the 49,884 listings being analyzed, 21,660 of them are located in Manhattan and 20,095 in Brooklyn. Staten Island shows up last with only 278 listings.
#
# We can use a pie chart to better visualize how the numbers are distributed in percentages:

# %%
df3 = df2.groupby('neighbourhood_group')['id'].count()

plt.figure(figsize=(10, 8))
colors = ['#272932', '#f05d5e', '#0f7173', '#9fc2cc', '#dbc648']

explode = (0, 0, 0.1, 0, 0)  # Explode the first slice for emphasis

sns.set(style='whitegrid')
sns.set_palette(sns.color_palette(colors))

df3.plot.pie(labels=df3.index, autopct='%1.0f%%', startangle=0, explode=explode,
             wedgeprops=dict(width=0.3), shadow=True)

plt.ylabel('Neighbourhood Group', fontsize=12)
plt.title('Total Listings by Neighbourhood Group', fontsize=16)

plt.axis('equal')  # Equal aspect ratio ensures a circular pie

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie plot is a good use case for finding the neighborhood group in the Airbnb 2019 NYC dataset with the most listingsIt shows how listings are distributed through proportional slices, each of which represents a neighborhood group and whose size reflects the proportion of listings. It is clear which neighborhood group has the largest slice and, consequently, the greatest number of listings by comparing the sizes of the slices. The distribution is easily understood by viewers and they can quickly determine which neighborhood group in NYC is most popular for lodging thanks to the pie plot's simple and intuitive design

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Visualizing the distribution of listings using a pie plot provides a clear and
# proportional representation of each neighborhood group's share.
#
# *   The pie plot helps identify the neighborhood group with the highest number of listings, indicating its popularity and demand among hosts and guests.
#
#   Hosts can leverage this information to optimize their listings by focusing on the most popular neighborhood group, potentially increasing their booking rates and profitability.
#
# *   Guests can benefit from knowing which neighborhood group offers a wider range
# of choices and better availability, enabling them to find accommodations that suit their preferences and needs.
#
# *   The insights gained from the pie plot analysis allow stakeholders to understand the dynamics of the NYC Airbnb market, identify potential opportunities for business expansion, and make informed decisions based on the popularity and demand for accommodations in different areas.
#
# *   By considering the distribution of listings across neighborhood groups, hosts and guests can align their strategies and choices with the preferences and trends observed in the market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Analyzing the distribution of listings across neighborhood groups can provide insights into the popularity and competitiveness of different areas.
#
# *   Identifying the most popular neighborhood group can help hosts focus their marketing efforts and optimize their listings.
#
# *   However, relying solely on the most popular neighborhood group may lead to oversupply, intense competition, and potential decreases in prices and profitability.
#
# *  It may also limit diversity and opportunities for hosts in other neighborhood groups.
#
# *  Hosts should consider factors beyond just the number of listings, such as location amenities and unique features of each neighborhood
#
# *  Maintaining a balanced approach and diversifying listings across multiple neighborhood groups can mitigate the risks associated with concentration.
#
# *  Adapting to market dynamics, monitoring trends, and identifying emerging neighborhood groups can ensure sustainable growth.
#
# * Hosts should continuously evaluate and adjust their strategies based on changes in demand, competition, and guest preferences.

# %% [markdown]
# #### Chart - 4   How does average availability vary with price ?

# %%
# Chart - 4 visualization code
# Group the data by 'neighbourhood_group' and calculate the average availability
availability_by_group = df2.groupby('price')['availability_365'].mean()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.lineplot(x=availability_by_group.index, y=availability_by_group.values, color='#f05d5e')

# Set the title and axis labels
plt.title('Average Availability of Listings by Price')
plt.xlabel('Price')
plt.ylabel('Average Availability (in days)')

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *  With the use of a line plot, analysts can learn more about the relationship between price ranges and the average availability of lodging in various neighborhood groups. The relationship between price and availability in the Airbnb 2019 NYC dataset can help hosts and guests make well-informed decisions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  The line plot allows us to observe how the availability of listings changes with respect to different price points within each neighborhood group.
#
# *   By analyzing the plot, we can determine whether higher prices are associated with higher or lower availability within a specific neighborhood group.
#
# *   The plot helps identify neighborhood groups that consistently maintain high availability regardless of the price range, indicating a higher likelihood of finding accommodations in those areas.
#
# *   Optimal price ranges for maximizing availability can be identified by examining the peaks and valleys of the line plot within each neighborhood group.
#
# *   Comparing the availability-price patterns across different neighborhood groups allows us to understand the variations in the relationship between availability and price, providing insights into the dynamics of the market.
#
#
# *  These insights aid decision-making for both hosts and guests. Hosts can adjust their pricing strategies to optimize availability and occupancy rates within specific neighborhood groups. Guests can identify price ranges where availability is higher, allowing them to make informed decisions when booking accommodations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Optimizing Pricing Strategies: The line plot allows hosts to identify the relationship between price and availability within each neighborhood group. This information enables hosts to strategically set prices that maximize availability while ensuring profitability. By finding the optimal price range, hosts can attract more guests and increase occupancy rates.
#
# * Informed Decision-Making for Guests: Guests can benefit from the line plot by understanding how availability changes with price in different neighborhood groups. This knowledge helps them make informed choices based on their budget and desired availability. Guests can identify price ranges where availability is higher, increasing their chances of finding suitable accommodations.
#
# *  Potential Risks: It is important to consider the potential risks associated with pricing strategies. Higher prices might lead to significantly lower availability, impacting guest bookings. Additionally, if the optimal price range falls outside the desired range for guests, it may deter potential bookings. Competing hosts may also drive down prices, affecting profitability.
#
#
# *  Balancing Pricing Strategies: To mitigate risks and promote positive growth, hosts should balance their pricing strategies. This includes considering factors beyond availability and price, such as unique features, amenities, and the overall value proposition of their listings. Differentiating offerings can help hosts stand out in a competitive market.
#
# *  Diversification: Hosts can diversify their offerings across different neighborhood groups to minimize risks and leverage opportunities. This allows them to cater to a broader range of guests with varying preferences and budgets.

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# #### Chart - 5  What is the average price of Airbnb listings in NYC in 2019, categorized by room type?

# %%
# Chart - 5 visualization code
# Select the relevant columns
df = df2[['neighbourhood_group', 'room_type', 'price']]

# Group the data by neighbourhood_group and room_type, and calculate the mean price
df = df.groupby(['neighbourhood_group', 'room_type'], as_index=False)[['price']].mean()

# Create a figure and set the theme to white
plt.figure(figsize=(12, 6))
sns.set_theme(style='white')

# creating palette
my_pal = {'Entire home/apt': '#f05f5e', 'Private room': '#ead94c', 'Shared room': '#0f7173'}

# Create a bar plot with x as neighbourhood_group, y as price, hue as room_type, and using the custom color palette
df = sns.barplot(x="neighbourhood_group", y="price", data=df, hue='room_type', palette=my_pal)

# Add annotations to the bars with the formatted average price values
for p in df.patches:
    df.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', size=11, xytext=(0, -12), textcoords='offset points')

# Set the x and y labels, and the title of the plot
plt.xlabel('Neighbourhood Group')
plt.ylabel('Average Price')
plt.title('Average Price by Room Type')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Airbnb 2019 NYC dataset shows the distribution of listing prices by type of room using a bar plot. With a distinct bar for each type of room, this plot makes it easy to compare prices between the categories. The height of every bar signifies the range or mean cost for that category of rooms, allowing spectators to recognize differences in costs among various kinds of lodging. Insights into pricing dynamics and trends for each type of room are provided by the bar plot, which helps hosts and guests make well-informed decisions based on their financial constraints and preferences

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Price Ranges and Differences: The bar plot allows for a visual representation of the price ranges and variations among different room types. Guests can quickly identify the price brackets associated with each room type, helping them narrow down their search and find accommodations that fit their budget.
#
# * Market Preferences and Unique Pricing Patterns: The bar plot provides insights into the popularity of different room types based on their frequency of occurrence and price distribution. It helps identify room types that are in high demand or preferred by guests. Additionally, the plot may reveal unique pricing patterns, such as certain room types being consistently priced higher or lower than others.
#
# * Informed Pricing Strategies: Hosts can leverage the information from the bar plot to make informed pricing decisions. By understanding the distribution of prices for different room types, hosts can set competitive and attractive prices for their listings. They can adjust their pricing strategy based on the popularity and demand for specific room types, maximizing their occupancy rates and potential profitability.
#
# * Accommodation Choices: Guests can utilize the bar plot to explore the range of accommodation options available for different room types and their corresponding prices. This allows guests to make informed choices based on their preferences and budget constraints. They can select room types that best meet their needs, whether it's a private room, an entire home, or a shared space.
#
# * Enhancing the Airbnb Experience: The insights gained from the bar plot contribute to an overall enhanced Airbnb experience in NYC. Guests can find accommodations that align with their budget and preferences, while hosts can optimize their pricing strategies to attract more bookings. This creates a win-win situation, improving guest satisfaction and the overall reputation of the Airbnb platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *  Optimizing Pricing Strategies: The bar plot provides valuable insights into the distribution of listing prices across different room types. Hosts can analyze the price ranges for each room type and adjust their pricing strategies accordingly. By understanding the pricing patterns, hosts can optimize their prices to attract guests while maximizing their profitability.
#
# * Meeting Guest Preferences: The bar plot helps identify the popularity of different room types based on their frequency of occurrence and price distribution. Hosts can use this information to align their offerings with guest preferences. By offering competitive prices for popular room types, hosts can attract more bookings and enhance guest satisfaction.
#
# * Mitigating Overpricing and Price Competition: The insights from the bar plot help hosts avoid overpricing certain room types. Consistently overpriced accommodations may deter potential guests and negatively impact business growth. Additionally, intense price competition among hosts offering the same room type can lead to lower profitability. Striking a balance between competitiveness and profitability is crucial for hosts to maintain positive business growth.

# %% [markdown]
# #### Chart - 6  Which room types are most often revived each month in each neighborhood?

# %%
# Chart - 6 visualization code
# Create a figure and axis object
f, ax = plt.subplots(figsize=(10, 8))

# Create a strip plot with room_type on x-axis, reviews_per_month on y-axis, and hue as neighbourhood_group
ax = sns.stripplot(x='room_type', y='reviews_per_month', hue='neighbourhood_group', dodge=True, data=df2, palette=['#272932', '#f05d5e', '#0f7173', '#9fc2cc', '#ead94c'])

# Set the title of the plot
ax.set_title('Most Reviewed Room Types in Each Neighbourhood Group')

# Remove the spines on the right and bottom sides of the plot for cleaner appearance
sns.despine(right=False, bottom=True)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By using a strip plot in the Airbnb 2019 NYC dataset, analysts can learn which room types receive the most reviews each month in each neighborhood.Hosts can use this visualization to inform their marketing and investment decisions by seeing which room types are in high demand. It also offers helpful information to visitors looking for well-liked lodging in particular areas and during particular times of the year

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Popular Room Types: The strip plot reveals the most reviewed room types in each neighborhood per month, helping hosts identify popular choices for guests.
#
# * Seasonal Trends: Hosts can observe seasonal patterns in room type popularity, allowing them to adjust pricing and availability accordingly.
#
# * Neighborhood Preferences: The strip plot highlights room type preferences within different neighborhoods, enabling hosts to tailor offerings to meet specific demands.
#
# * Outlier Detection: Outliers in the plot indicate room types with significantly higher or lower reviews, providing insights for hosts to understand unique selling points or areas for improvement.
#
# * Informed Decision-Making: Both hosts and guests can make more informed choices based on the insights from the strip plot.
#
# * Enhanced Guest Satisfaction: By offering highly reviewed room types, hosts can increase the likelihood of delivering a positive guest experience.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Enhanced Marketing: Analyzing the most reviewed room types in each neighborhood per month using a strip plot provides valuable insights for hosts to tailor their marketing efforts and attract more guests.
#
# * Increased Bookings: By understanding popular room types, hosts can optimize their offerings and increase bookings, resulting in positive business growth.
#
# * Diversification: To mitigate the risk of limited availability and overlooking other room types, hosts should maintain a diverse range of offerings to cater to different guest preferences.
#
# * Adaptation to Market Demands: Adapting to market demands and trends is crucial for hosts to ensure continued positive business growth and avoid stagnation.

# %% [markdown]
# #### Chart - 7  How does the distribution of listing prices vary across different room types?

# %%
# Chart - 7 visualization code
# Set figure size
plt.figure(figsize=(10, 6))

# Set seaborn theme to whitegrid
sns.set_theme(style="whitegrid")

# Customize color palette
colors = ['#f05d5e','#dbc648','#9fc2cc']
sns.violinplot(x="room_type", y="price", data=df2, palette=colors)

# Set axis labels and title
plt.xlabel('Room Type', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.title('Distribution of Price by Room Type', fontsize=14)

# Adjust tick label font size
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)

# Remove top spine
sns.despine(right=False)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * By using a violin plot Analysts can learn more about how listing prices in the Airbnb 2019 NYC dataset differ for various types of rooms.In order to help hosts and guests make informed decisions based on their expectations and preferences for pricing, it helps to understand the range, shape, and skewness of the price distributions for each type of room.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The violin plot provides insights into the distribution of listing prices across different room types in the Airbnb 2019 NYC dataset.
#
# * It visually represents the variation in price ranges, central tendency, skewness, and potential outliers for each room type.
#
# * Hosts and guests can use this information to understand the pricing landscape and make informed decisions.
#
# * The plot helps guests identify accommodations that align with their budget and preferences.
#
# * It allows hosts to assess the competitiveness and uniqueness of their pricing strategies.
#
# * The violin plot enhances the overall understanding of listing prices across room types, contributing to an improved Airbnb experience in NYC.

# %% [markdown]
#  ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Analyzing the distribution of listing prices across different room types using a violin plot in the Airbnb 2019 NYC dataset provides valuable insights.
#
# * Hosts can optimize pricing strategies based on the observed price ranges and distributions to attract more bookings and increase revenue.
#
# It is important to strike a balance between competitiveness and profitability to avoid negative growth.
#
# * Consistently overpricing certain room types can lead to decreased demand.
# Intense price competition can also pose challenges.
#
# * Hosts should consider market dynamics and guest preferences to ensure sustainable business growth.
#
#
# * By leveraging the insights from the violin plot, hosts can make informed decisions to maximize profitability and provide an enhanced experience for guests in the NYC Airbnb market.

# %% [markdown]
# #### Chart - 8 Group the dataset by room type and calculate the average price

# %%
# Chart - 8 visualization code
# Group the dataset by room type and calculate the average price
room_type_avg_price = df2.groupby('room_type')['price'].mean().reset_index()

# Set the style and color palette
sns.set(style='whitegrid')
pal=['#f05d5e','#dbc648','#9fc2cc']

# Create a bar plot to visualize the average price by room type
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='room_type', y='price', data=room_type_avg_price, palette = pal)

# Add labels to the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', size=11, xytext=(0, -12), textcoords='offset points')

# Set the title and axis labels
plt.title('Average Price by Room Type', fontsize=16)
plt.xlabel('Room Type', fontsize=12)
plt.ylabel('Average Price', fontsize=12)

# Remove the top and right spines
sns.despine()

# Adjust the layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By using a bar plot analysts can learn more about the average costs connected to various room types in the Airbnb 2019 NYC dataset.It makes it easier to comprehend how much different lodging options cost, enabling both hosts and guests to choose wisely depending on their preferences and financial constraints.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The bar plot displaying the average prices by room types in the Airbnb 2019 NYC dataset provides valuable insights.
#
# * It allows for easy comparison of average prices, revealing variations in pricing between different types of accommodations.
#
# * The chart helps identify preferred room types and informs pricing strategies for hosts.
#
# * It also influences guests' perception of value, as they can compare prices across different room types.
#
#
# * The bar plot provides a broader understanding of the pricing landscape in the Airbnb market in NYC.
#
#
# * It aids in market analysis and decision-making by providing insights into pricing trends and patterns.
#
#
# * The insights from the bar plot contribute to informed pricing decisions, improved guest experiences, and a better understanding of the market dynamics in the Airbnb 2019 NYC dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * The insights gleaned from examining the average costs for various room types in the Airbnb 2019 NYC dataset could have a favorable effect on business.
#
# * Based on the average prices that have been observed, hosts can optimize their pricing strategies in an effort to gain a competitive edge in the market.
#
# * Comprehending the mean costs for various categories of rooms enables hosts to make well-informed choices that enhance guest attraction and bookings.
#
# * However, there is a risk of negative growth if certain room types are consistently overpriced, as it may deter potential guests and decrease demand.
#
# * Hosts should strike a balance between competitiveness and profitability, considering market dynamics and guest preferences.
#
# * It is essential to regularly monitor and adjust prices to ensure sustainable business growth and maintain a competitive edge in the market.

# %% [markdown]
# #### Chart - 9 What is the number of reviews for Airbnb listings in NYC in 2019, segmented by room type?

# %%
# Chart - 9 visualization code
# Set figure size
plt.figure(figsize=(10, 6))

# Set seaborn theme to whitegrid
sns.set_theme(style="whitegrid")

# Custom color palette
colors = ['#f05d5e','#0f7173','#dbc648']

# Create the bar plot
ax = sns.barplot(x="room_type", y="number_of_reviews", data=df2, palette=colors)

# Set the title and axis labels
plt.title('Number of Reviews by Room Type', fontsize=16)
plt.xlabel('Room Type', fontsize=12)
plt.ylabel('Number of Reviews', fontsize=12)

# Remove the top and right spines
sns.despine()

# Adjust the plot layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By utilizing a bar plot, analysts can gain insights into the number of reviews received by different room types in the Airbnb 2019 NYC dataset. It helps in understanding the level of engagement and feedback for each room type, enabling hosts and guests to make informed decisions based on the popularity and perceived quality of accommodations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The insights gained from analyzing the number of reviews by room types in the Airbnb 2019 NYC dataset provide valuable information.
#
# * The bar plot showcases the popularity of different room types based on the number of reviews, indicating guest preferences and satisfaction levels.
#
# * Hosts can use this information as a performance metric to evaluate the success of their listings and make informed decisions regarding room types.
#
# * The number of reviews serves as social proof for guests, influencing their decision-making process and providing insights into the quality and reliability of accommodations.
#
# * Understanding the popularity of different room types helps hosts optimize their offerings and cater to guest preferences, ultimately enhancing the overall Airbnb experience in NYC.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * The insights gained from analyzing the number of reviews by room types in the Airbnb 2019 NYC dataset have the potential to create a positive business impact.
#
# * Higher review counts indicate increased bookings and reflect guest satisfaction and preferences.
#
# * Positive reviews contribute to improved reputation and credibility for hosts, attracting more guests and increasing bookings.
#
# * However, it's important to manage negative reviews and address any issues to maintain a positive reputation.
#
# * A lack of diversity in offerings or consistently negative reviews can lead to negative growth and decreased bookings.
#
# * Striving for a balanced and positive reputation through quality accommodations and excellent guest experiences is crucial for sustainable business success.

# %% [markdown]
# #### Chart - 10 What is the distribution of room types across different neighborhood groups in NYC?

# %%
# Chart - 10 visualization code
# Set figure size
plt.figure(figsize=(13, 7))

# Set title
plt.title("Room Type on Neighbourhood Group")

# Defining the desired color palette
colors = ['#41d3bd', '#f05d5e', '#272932']

# Setting the theme and color palette for the plot
sns.set_theme(style="whitegrid", palette=colors)

# Creating a countplot showing the distribution of room types in each neighbourhood group
sns.countplot(x=df2.neighbourhood_group, hue=df2.room_type)

plt.xlabel('Neighbourhood Group')
plt.ylabel('Count')

# Add a legend for the room types
plt.legend(title='Room Type')

# Adjust the plot layout
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *  The specific chart chosen is a countplot showing the distribution of room types in each neighborhood group. This chart was selected because it effectively visualizes the relationship between the categorical variables "neighbourhood_group" and "room_type" by displaying the counts of each room type within each neighborhood group. It allows for easy comparison and identification of the dominant room types in different neighborhood groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart provides insights into the distribution of room types across different neighborhood groups.
#
# * It helps identify the most common room type in each neighborhood group.
#
# * It reveals any variations in room type distribution between neighborhood groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * The gained insights can positively impact business by informing marketing strategies and target audience selection.
#
# * They can help hosts optimize pricing and revenue by aligning with prevalent room types in each neighborhood group.
#
# * The insights assist in resource allocation and inventory management based on demand patterns.
#
# * No insights from the chart directly lead to negative growth. However, a limited distribution of room types in a neighborhood group may require hosts to consider diversifying offerings or targeting alternative markets to mitigate potential negative impacts.

# %% [markdown]
# #### Chart - 11  Is there a correlation between the price of Airbnb rentals and the number of reviews they receive in NYC?

# %%
# Chart - 11 visualization code
# A scatter plot to analyze the correlation between price and number of reviews
plt.figure(figsize=(10, 8))
sns.scatterplot(x='number_of_reviews', y='price', data=df2, alpha=0.35, color = '#0F7173')

# Defining the labels
plt.xlabel('Number of Reviews')
plt.ylabel('Price')
plt.title('Price vs. Number of Reviews of Airbnb Rentals')

#change the grid design
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# REmove top and right spine
sns.despine()

#display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * The specific chart chosen is a scatter plot that analyzes the correlation between the price and the number of reviews for Airbnb rentals. This chart was selected because it allows for the examination of the relationship between two continuous variables, "price" and "number_of_reviews," by plotting each data point as a dot on the graph. It helps visualize any potential patterns or trends between the variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The scatter plot shows the relationship between the price and the number of reviews for Airbnb rentals.
#
#
# * It helps identify any patterns or trends between the two variables.
#
#
# * It can reveal the presence of outliers or unusual observations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * The gained insights can help hosts optimize their pricing strategy based on the correlation between price and the number of reviews.
#
# * It enables hosts to focus on reputation management by encouraging reviews and monitoring feedback.
#
# *  The insights can highlight areas for improvement in order to enhance guest satisfaction and increase positive reviews.
#
#
# * The absence of a significant correlation between price and the number of reviews may indicate a need to reassess the rental's value proposition and address any underlying issues.

# %% [markdown]
# Multi Variate Analysis

# %% [markdown]
# #### Chart - 12 How does the price of properties vary based on their location in NYC?

# %%
# Chart - 12 visualization code
#saved the original map image on my github repository and read the image using imread function
from skimage.io import imread
from matplotlib.colors import ListedColormap

plt.figure(figsize=(10,7))

# Load the map image using the imread function
img=imread('https://raw.githubusercontent.com/animeshmahajan8/Capstone-Project-Airbnb-NYC-2019-EDA/Working/New_York_City_District_Map.png')


# Define your custom colors
custom_colors = ['#272932', '#f05d5e','#0f7173','#9fc2cc','#dbc648',]

# Create a custom colormap
custom_cmap = ListedColormap(custom_colors)

# Display the map image
plt.imshow(img,zorder=0,extent=[df2['longitude'].min(),df2['longitude'].max(),df2['latitude'].min(),df2['latitude'].max()])
ax = plt.gca()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * The specific chart chosen is a scatter plot overlaid on a map image of New York City. This chart was selected to visualize the geographical distribution of Airbnb rental prices across different neighborhoods. It combines location information (latitude and longitude) with the price variable, providing a spatial understanding of price trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Geographical price distribution: The chart shows the variation in rental prices across different neighborhoods in New York City.
#
# * Spatial patterns: It helps identify clusters of high or low-priced rentals in specific areas of the city.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * The insights gained from the chart can have a positive business impact by guiding pricing strategies, targeting specific markets, and identifying investment opportunities. However, it's crucial to consider areas with consistently low prices or oversaturation of listings to avoid negative growth prospects.

# %% [markdown]
# #### Chart - 13 Identifying the top 30 busiest Airbnb hosts based on average review rates and exploring the distribution of review rates across different room types for these hosts.

# %%
# Chart - 13 visualization code
# Create a series of top 30 hosts by review rate
review_rate = df2.groupby('host_id')['reviews_per_month'].mean().head(40).reset_index()
review_rate.sort_values('reviews_per_month', ascending=False, inplace=True)
review_rate = review_rate.iloc[:, 0]

# Create a new dataframe containing information of only these top 30 hosts
Top_host_by_review_rate = df2.loc[df2['host_id'].isin(review_rate)]
Top_host_by_review_rate = Top_host_by_review_rate.sort_values('reviews_per_month')

# Define a custom Palete
custom_colors = ['#272932', '#f05d5e', '#0f7173', '#9fc2cc', '#dbc648']

# Create a catplot to visualize the review rates of these top 30 hosts by room type
fig = sns.catplot(data=Top_host_by_review_rate, x='host_id', y='reviews_per_month',col='room_type', kind='bar', height=2, aspect=8, palette = custom_colors)
fig.set_xticklabels(rotation=90)
fig.fig.set_size_inches(20, 10)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * The specific chart chosen is a catplot bar chart that visualizes the review rates of the top 30 hosts by room type. This chart was selected to compare the review rates of these hosts across different room types and identify any variations or patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Comparison by room type: The chart allows for a comparison of review rates among the top hosts across different room types, such as entire homes/apartments, private rooms, and shared rooms.
#
# * Variations in review rates: The chart reveals any discrepancies in review rates among the top hosts, highlighting differences in performance across room types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Quality improvement: Hosts can identify areas for improvement based on review rates and focus on enhancing the guest experience in specific room types with lower rates.
#
# * Competitive advantage: Higher review rates can be leveraged as a competitive advantage in marketing efforts to attract more guests and build a strong reputation.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Define a custom color palette
custom_colors = ['#dbc648', '#9fc2cc','#0f7173','#f05d5e', '#272932']

# Defining the correlation function
plt.figure(figsize=(12, 6))
corr = df2.corr()

# Visualize correlations as a heatmap with the custom color palette
sns.heatmap(corr, cmap=custom_colors, annot=True)

# Display the heatmap
plt.show()
# Out:
# <ipython-input-77-71895f863b86>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df2.corr()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# ---

# %% [markdown]
# * The correlation heatmap was chosen because it provides a comprehensive overview of the relationships between variables in the dataset. It allows for easy identification of patterns and associations between different features, helping to uncover potential insights and understand the underlying structure of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The heatmap provides visual representation of correlations between variables in the Airbnb 2019 NYC dataset.
#
# * Lighter colors indicate positive correlations, suggesting that as one variable increases, the other tends to increase as well.
#
# * Darker colors represent negative correlations, indicating that as one variable increases, the other tends to decrease.
#
# * Areas without distinct color patterns indicate weak or no correlations between variables.
#
# * The insights gained from the heatmap can help understand the interdependencies between variables and their relationships.
#
# * These insights can inform decision-making processes by identifying strong correlations and potential factors influencing certain outcomes

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
